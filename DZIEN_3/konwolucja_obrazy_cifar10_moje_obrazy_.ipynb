# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# %%
#ładowanie obrazów CIFAR10
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
#pobieranie obrazów
image_path = 'image.jpg'
image = tf.io.read_file(image_path)
image = tf.image.decode_jpeg(image, channels=3)
image = tf.image.resize(image, [128, 96])
image = tf.expand_dims(image, axis=0)

image = tf.image.convert_image_dtype(image, tf.float32) #normalizacja [0,1]
image = tf.image.resize(image, [512, 324])

# %%
#normalizacja danych wejściowych
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# %%
#konwersja etykiet na postac one-hot
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
#budowa modelu sieci konwolucyjnej (CNN)
model = models.Sequential([
    layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)),
    layers.BatchNormalization(),
    layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.4),

    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(10, activation='softmax')
])

model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 32, 32, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 32, 32, 32)          │             128 │
# ...

# %%
#kompilacja modelu
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
#trenowanie modelu
history = model.fit(x_train, y_train, epochs=10, batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 407s 651ms/step - accuracy: 0.3541 - loss: 2.0271 - val_accuracy: 0.5321 - val_loss: 1.3622
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 421s 618ms/step - accuracy: 0.5647 - loss: 1.2542 - val_accuracy: 0.4885 - val_loss: 1.7171
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 387s 619ms/step - accuracy: 0.6503 - loss: 0.9832 - val_accuracy: 0.7126 - val_loss: 0.8209
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 444s 622ms/step - accuracy: 0.7092 - loss: 0.8334 - val_accuracy: 0.7019 - val_loss: 0.8698
# Epoch 5/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 433s 609ms/step - accuracy: 0.7285 - loss: 0.7718 - val_accuracy: 0.7583 - val_loss: 0.7081
# Epoch 6/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 384s 612ms/step - accuracy: 0.7599 - loss: 0.6837 - val_accuracy: 0.7602 - val_loss: 0.6966
# Epoch 7/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 447s 620ms/step - accuracy: 0.7773 - loss: 0.6338 - val_accuracy: 0.8025 - val_loss: 0.5692
# Epoch 8/10
# ...

# %%
#ewaluacja modelu
test_loss, test_acc = model.evaluate(x_test, y_test)
print('Test accuracy:', test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 22s 72ms/step - accuracy: 0.7861 - loss: 0.6418
# Test accuracy: 0.7871999740600586

# %%
#wykonanie predykcji na danych testowych
predictions = model.predict(x_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 28s 88ms/step

# %%
#funkcja wizualizująca wyniki predykcji
def visalize_predictions(x_test,y_test,predictions, class_names, num_samples=10):
  plt.figure(figsize=(6,6))
  for i in range(num_samples):
    plt.subplot(5,5,i+1)
    plt.imshow(x_test[i])
    plt.axis('off')
    predicted_class = np.argmax(predictions[i])
    true_class = np.argmax(y_test[i])
    if predicted_class == true_class:
      plt.title(f"Predicted: {class_names[predicted_class]}\nTrue: {class_names[true_class]}",
                color='green',fontsize=8)
    else:
      plt.title(f"Predicted: {class_names[predicted_class]}\nTrue: {class_names[true_class]}",
                color='red',fontsize=8)
  plt.tight_layout()
  plt.show()

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
visalize_predictions(x_test,y_test,predictions, class_names)
